# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

def load_data(path):

    df = pd.read_csv(path)

    df.drop("customerID", axis=1, inplace=True)

    return df


def preprocess_data(df):

    le = LabelEncoder()

    for col in df.columns:
        if df[col].dtype == "object":
            df[col] = le.fit_transform(df[col])

    X = df.drop("Churn", axis=1)
    y = df["Churn"]

    scaler = StandardScaler()

    X_scaled = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y, test_size=0.2, random_state=42
    )

    return X_train, X_test, y_train, y_test, scaler

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout


def build_ann(input_dim):

    model = Sequential()

    model.add(Dense(64, activation='relu', input_dim=input_dim))

    model.add(Dropout(0.3))

    model.add(Dense(32, activation='relu'))

    model.add(Dense(16, activation='relu'))

    model.add(Dense(1, activation='sigmoid'))

    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# pipelines

# %%
import pandas as pd

data_path = "/content/WA_Fn-UseC_-Telco-Customer-Churn.csv"

df = load_data(data_path)

X_train, X_test, y_train, y_test, scaler = preprocess_data(df)

model = build_ann(X_train.shape[1])

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)

loss, acc = model.evaluate(X_test, y_test)

print("Test Accuracy:", acc)

model.save("models/churn_ann_model.h5")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6363 - loss: 0.6082 - val_accuracy: 0.7799 - val_loss: 0.4265
# Epoch 2/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7760 - loss: 0.4565 - val_accuracy: 0.8048 - val_loss: 0.4183
# Epoch 3/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7849 - loss: 0.4377 - val_accuracy: 0.7941 - val_loss: 0.4180
# Epoch 4/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7900 - loss: 0.4300 - val_accuracy: 0.7977 - val_loss: 0.4144
# Epoch 5/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7840 - loss: 0.4385 - val_accuracy: 0.8012 - val_loss: 0.4104
# ...

# %%
import numpy as np
import tensorflow as tf

model = tf.keras.models.load_model("models/churn_ann_model.h5")

# The original data had 19 features after preprocessing (excluding customerID and Churn).
# This sample customer array needs to match that dimension.
# For demonstration, I'm using a placeholder 19-feature array.
# In a real scenario, you would need to apply the same label encoding and scaling
# used during training to a new raw customer's data.
# For now, let's create a dummy 19-feature array and then scale it.
# X_train.shape[1] is 19. X_test also has 19 features.
# The `scaler` object is available in the kernel state.
# A sample customer would need to be in the same format as X_train/X_test
# sample_customer_raw = np.array([...19 values representing a customer's raw features...])
# sample_customer_encoded = le.transform(sample_customer_raw) # if relevant

# For simplicity, let's create a dummy 19-feature input and scale it
# In a real application, you would preprocess a new customer's data.
# Here, we'll take the first sample from X_test as an example to make a valid prediction.
# To predict for a new customer, you'd need to create an array with 19 features
# that are properly encoded and then scaled with the saved scaler.

# Using the first customer from X_test to demonstrate a valid prediction input
sample_customer_scaled = X_test[0:1]

prediction = model.predict(sample_customer_scaled)

if prediction > 0.5:
    print("Customer will churn")
else:
    print("Customer will stay")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# Customer will stay

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,batch_size=32,epochs=55,initial_epoch=50,validation_data=(X_test,y_test))
# Out:
# Epoch 51/55
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8089 - loss: 0.4010 - val_accuracy: 0.8077 - val_loss: 0.4151
# Epoch 52/55
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8178 - loss: 0.4016 - val_accuracy: 0.8034 - val_loss: 0.4129
# Epoch 53/55
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8207 - loss: 0.3826 - val_accuracy: 0.8055 - val_loss: 0.4126
# Epoch 54/55
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8296 - loss: 0.3754 - val_accuracy: 0.8126 - val_loss: 0.4134
# Epoch 55/55
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8268 - loss: 0.3785 - val_accuracy: 0.7999 - val_loss: 0.4150
